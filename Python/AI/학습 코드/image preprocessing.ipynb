# %%
import cv2
import matplotlib.pyplot as plt
import numpy as np
import os

# %%
# 데이터 가져오기
data_dir = os.path.join('..', 'DL_Data', 'imgset')
img_dir = os.path.join(data_dir, 'airplane.jpg')  # 경로 수정: 불필요한 '/' 제거
img = cv2.imread(img_dir, cv2.IMREAD_COLOR)  # 이미지 경로를 직접 사용
print(img_dir)
plt.imshow(cv2.cvtColor(img, cv2.COLOR_BGR2RGB))
# Out:
# ..\DL_Data\imgset\airplane.jpg
